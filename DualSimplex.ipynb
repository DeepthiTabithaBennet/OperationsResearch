# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiTabithaBennet/OperationsResearch/blob/main/DualSimplex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Written by Deepthi Tabitha Bennet

# %%
from scipy.optimize import linprog
import numpy as np

# %%
obj_num = int(input("Enter the number of variables in the Objective Function : "))
obj = []

print("Enter the Coefficients of the variables in the Objective Function : ")
for i in range(0, obj_num):
    x = int(input())
    obj.append(x)

print("\nObjective Function : ", obj)

# ---------------------------------------------------------------------------------------

const_num = int(input("\n\nEnter the number of Constraint Equations : "))
lhs = []
rhs = []
intermed = []

print("Enter the LHS of the Constraint Equations : ")
for i in range(0, const_num):
    print("\nConstraint Equation", (i+1))
    for j in range(0, obj_num):
        y = int(input())
        intermed.append(y)
    lhs.append(intermed)
    intermed = []

print("\nConstraint Equations (LHS) : ", lhs)

# ---------------------------------------------------------------------------------------

print("\n\nEnter the RHS of the Constraint Equations : ")
for i in range(0, const_num):
    x = int(input())
    rhs.append(x)

print("\nConstraint Equations (RHS) : ", rhs)

# ---------------------------------------------------------------------------------------

print("\n\n")
# Out:
# Enter the number of variables in the Objective Function : 5
# Enter the Coefficients of the variables in the Objective Function :
# 5
# -6
# 1
# 9
# 3
#
# Objective Function :  [5, -6, 1, 9, 3]
#
#
# Enter the number of Constraint Equations : 3
# Enter the LHS of the Constraint Equations :
#
# Constraint Equation 1
# 8
# 5
# 3
# 5
# 2
#
# Constraint Equation 2
# 9
# 2
# 4
# 1
# 7
#
# Constraint Equation 3
# 1
# 5
# 3
# 8
# 6
#
# Constraint Equations (LHS) :  [[8, 5, 3, 5, 2], [9, 2, 4, 1, 7], [1, 5, 3, 8, 6]]
#
#
# Enter the RHS of the Constraint Equations :
# 2
# 6
# 4
#
# Constraint Equations (RHS) :  [2, 6, 4]

# %%
optimize = linprog(c = obj,
                  A_ub = lhs,
                  b_ub = rhs,
                  # bounds = (0, float('inf')),
                  method = 'highs-ds')
print(optimize)
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -2.4000000000000004
#               x: [ 0.000e+00  4.000e-01  0.000e+00  0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  4.000e-01  0.000e+00  0.000e+00
#                               0.000e+00]
#                  marginals: [ 1.460e+01  0.000e+00  4.600e+00  1.500e+01
#                               5.400e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  5.200e+00  2.000e+00]
#                  marginals: [-1.200e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
