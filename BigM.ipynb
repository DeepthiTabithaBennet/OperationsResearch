# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiTabithaBennet/OperationsResearch/blob/main/BigM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Written By Deepthi Tabitha Bennet

# %%
# Source - https://github.com/Capital2/Big-M

! pip install BigM

# %%
from BigM import BigM
from BigM import graph
from BigM import InputHandling
import numpy as np

lp = input("Enter the Objective Function, and the Constraint Equations, Separated by Spaces : ").split()
print("System of Equations : ", lp)

bm = BigM.BigM()
formattedInput = np.array(InputHandling.formatUserInput(lp))

results = bm.runBigM(formattedInput)
# Out:
# Enter the Objective Function, and the Constraint Equations, Separated by Spaces : MaxZ=x+5y 6x+5y<=60 x+2y<=14 x<=9
# System of Equations :  ['MaxZ=x+5y', '6x+5y<=60', 'x+2y<=14', 'x<=9']

# %%
print(results)
# Out:
# [(   x1  x2  s1  s2  s3  p  condition  ratio operations
# 0   6   5   1   0   0  0         60      0    DEFAULT
# 1   1   2   0   1   0  0         14      0    DEFAULT
# 2   1   0   0   0   1  0          9      0    DEFAULT
# 3  -1  -5   0   0   0  1          0      0    DEFAULT, [('s1', 60, 0), ('s2', 14, 1), ('s3', 9, 2)], [('x1', 0, -1), ('s2', 0, -1)]), (    x1  x2  s1   s2  s3  p  condition  ratio      operations
# 0  3.5   0   1 -2.5   0  0         25   12.0  L0<-L0+(-5*LP)
# 1  0.5   1   0  0.5   0  0          7    7.0    LP<-(1/2)*LP
# 2  1.0   0   0  0.0   1  0          9    inf         DEFAULT
# 3  1.5   0   0  2.5   0  1         35    0.0   L3<-L3+(5*LP), [('s1', 25, 0), ('s3', 9, 2), ('x2', 7, 1)], [('x1', 0, -1), ('s2', 0, -1)])]

# %%
# Not Needed
graph.drawGraph(formattedInput, slider=True)
