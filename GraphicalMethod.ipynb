# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiTabithaBennet/OperationsResearch/blob/main/GraphicalMethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Written by Deepthi Tabitha Bennet

# %%
! pip install gilp

# %%
import gilp
import numpy as np
from gilp.simplex import LP

# %%
obj_num = int(input("Enter the number of variables in the Objective Function : "))
obj = []

print("Enter the Coefficients of the variables in the Objective Function : ")
for i in range(0, obj_num):
    x = int(input())
    obj.append(x)

print("\nObjective Function : ", obj)

# ---------------------------------------------------------------------------------------

const_num = int(input("\n\nEnter the number of Constraint Equations : "))
lhs = []
rhs = []
intermed = []

print("Enter the LHS of the Constraint Equations : ")
for i in range(0, const_num):
    print("\nConstraint Equation", (i+1))
    for j in range(0, obj_num):
        y = int(input())
        intermed.append(y)
    lhs.append(intermed)
    intermed = []

print("\nConstraint Equations (LHS) : ", lhs)

# ---------------------------------------------------------------------------------------

print("\n\nEnter the RHS of the Constraint Equations :  : ")
for i in range(0, const_num):
    x = int(input())
    rhs.append(x)

print("\nConstraint Equations (RHS) : ", rhs)

# ---------------------------------------------------------------------------------------

print("\n\n")

obj = np.array(obj)
lhs = np.array(lhs)
rhs = np.array(rhs)
# Out:
# Enter the number of variables in the Objective Function : 2
# Enter the Coefficients of the variables in the Objective Function :
# 5
# 3
#
# Objective Function :  [5, 3]
#
#
# Enter the number of Constraint Equations : 3
# Enter the LHS of the Constraint Equations :
#
# Constraint Equation 1
# 2
# 1
#
# Constraint Equation 2
# 1
# 1
#
# Constraint Equation 3
# 1
# 0
#
# Constraint Equations (LHS) :  [[2, 1], [1, 1], [1, 0]]
#
#
# Enter the RHS of the Constraint Equations :  :
# 20
# 16
# 7
#
# Constraint Equations (RHS) :  [20, 16, 7]

# %%
lp = LP(lhs, rhs, obj)

# %%
from gilp.visualize import simplex_visual
simplex_visual(lp)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
